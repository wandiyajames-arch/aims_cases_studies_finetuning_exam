# %% [markdown]
# ### Mount Google Drive

# %%
# Connect to your Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/aims_cases_studies_finetuning_exam-main
# Out:
# /content/drive/MyDrive/aims_cases_studies_finetuning_exam-main

# %%
ls
# Out:
# configs/       inference_lora_qwen3_wolof.py  src/
# data/          push_to_hub.py                 templates/
# evaluation.py  README.md                      train_lora_assistant_only.py
# hf_space/      requirements.txt

# %% [markdown]
# ### Install Dependencies

# %%
# Install the required libraries
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.1/825.1 kB 22.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.1/555.1 kB 32.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 30.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# ...

# %% [markdown]
# ### Data Pipeline

# %%
# Run the data preparation script
# !python src/download_datasets.py all \
  --validation-ratio 0.05 \
  --eval-ratio 0.05
# Out:
# Loading CohereLabs/aya_dataset Wolof rows...
# ...
# README.md: 100% 13.7k/13.7k [00:00<00:00, 7.91MB/s]
# Saving aya source rows: 2914
# Loading soynade-research/Wolof-Non-Standard-Orthography rows...
# README.md: 100% 3.81k/3.81k [00:00<00:00, 8.74MB/s]
# Saving soynade source rows: 3438
# Saved synth rows: 5300
# Saved chat file for aya: 2914 rows -> /content/drive/MyDrive/aims_cases_studies_finetuning_exam-main/data/chat_aya.json
# Saved aya train: 2622 rows -> /content/drive/MyDrive/aims_cases_studies_finetuning_exam-main/data/splits/chat_aya_train.json
# Saved aya validation: 146 rows -> /content/drive/MyDrive/aims_cases_studies_finetuning_exam-main/data/splits/chat_aya_validation.json
# Saved aya eval: 146 rows -> /content/drive/MyDrive/aims_cases_studies_finetuning_exam-main/data/splits/chat_aya_eval.json
# Saved chat file for soynade: 3438 rows -> /content/drive/MyDrive/aims_cases_studies_finetuning_exam-main/data/chat_soynade.json
# ...

# %% [markdown]
# ### Run the Quick Test

# %%
# !python train_lora_assistant_only.py \
  --config configs/wolof_training_config.yml \
  --model-choice qwen \
  --max-train-examples 100 \
  --epochs 1 \
  --no-checkpoint-eval \
  --no-use-config-hparams
# Out:
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Assistant-only training enabled.
# Labels are -100 for system/user/padding tokens; loss is only on assistant outputs.
# Training config: /content/drive/MyDrive/aims_cases_studies_finetuning_exam-main/configs/wolof_training_config.yml
# Model choice: qwen
# Base model: Qwen/Qwen3-0.6B
# Training data: YAML training_data entries
# Output directory: /content/drive/MyDrive/aims_cases_studies_finetuning_exam-main/outputs/qwen3_0_6b_wolof_lora
# ...
# Loaded 2622 rows from config source aya: /content/drive/MyDrive/aims_cases_studies_finetuning_exam-main/data/splits/chat_aya_train.json
# ...

# %%
# !pip install --upgrade torchao peft
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 55.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
# ...

# %% [markdown]
# ### Full Training Job

# %%
# !python train_lora_assistant_only.py \
  --config configs/wolof_training_config.yml \
  --model-choice qwen
# Out:
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Assistant-only training enabled.
# Labels are -100 for system/user/padding tokens; loss is only on assistant outputs.
# Training config: /content/drive/MyDrive/aims_cases_studies_finetuning_exam-main/configs/wolof_training_config.yml
# Model choice: qwen
# Base model: Qwen/Qwen3-0.6B
# Training data: YAML training_data entries
# Output directory: /content/drive/MyDrive/aims_cases_studies_finetuning_exam-main/outputs/qwen3_0_6b_wolof_lora
# ...
# Loaded 2622 rows from config source aya: /content/drive/MyDrive/aims_cases_studies_finetuning_exam-main/data/splits/chat_aya_train.json
# ...

# %% [markdown]
# ### Hugging login

# %%
# !hf auth login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? [y/N]: y
# Token is valid (permission: write).
# The token `exam-token` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# ...

# %%
# !python push_to_hub.py \
  --adapter-dir outputs/qwen3_0_6b_wolof_lora/best_adapter \
  --repo-id wandiya39/qwen3-0.6b-wolof-lora
# Out:
# Authenticated Hugging Face user: wandiya39
# Model choice: qwen
# Base model: Qwen/Qwen3-0.6B
# Selected adapter source (final_fallback): /content/drive/MyDrive/aims_cases_studies_finetuning_exam-main/outputs/qwen3_0_6b_wolof_lora/best_adapter
# Clean upload folder: /content/drive/MyDrive/aims_cases_studies_finetuning_exam-main/outputs/qwen3_0_6b_wolof_lora/best_adapter/hub_upload_adapter
# Repository visibility set to private.
# Uploading clean adapter files only.
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   ...ad_adapter/tokenizer.json: 100% 11.4M/11.4M [00:00<?, ?B/s]
#
# Processing Files (1 / 2)      :  22% 11.4M/51.8M [00:00<00:02, 18.9MB/s,   ???B/s  ]
#
#
#   ...adapter_model.safetensors:   1% 559k/40.4M [00:00<?, ?B/s]
#
#   ...ad_adapter/tokenizer.json: 100% 11.4M/11.4M [00:00<?, ?B/s]
#
#
# Processing Files (1 / 2)      :  23% 12.0M/51.8M [00:00<00:03, 12.7MB/s, 1.15MB/s  ]
# ...
